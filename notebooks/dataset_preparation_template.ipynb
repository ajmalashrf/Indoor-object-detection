# %% [markdown]
# # Dataset Preparation Template
# Use this notebook to inspect class balance, verify annotations, and prepare indoor object detection data.

# %%
from pathlib import Path
import pandas as pd

dataset_dir = Path('data')
annotations_file = dataset_dir / 'annotations.csv'
annotations = pd.read_csv(annotations_file)
annotations.head()
